# %%
import gymnasium as gym
import gymnasium_robotics
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv
from stable_baselines3.common.vec_env import VecNormalize

# %%
def setup_video_recorder(env, video_folder='videos/', record_freq=10000, video_length=200):
    """
    Wrap the environment with a video recorder to capture agent performances.
    """
    env = VecVideoRecorder(
        env,
        video_folder,
        record_video_trigger=lambda step: step % record_freq == 0,
        video_length=video_length,
        name_prefix='rl-agent'
    )
    return env

def setup_checkpoint_callback(checkpoint_dir='checkpoints/', save_freq=1000):
    """
    Create a callback that saves the model at regular intervals.
    """
    checkpoint_callback = CheckpointCallback(
        save_freq=save_freq,
        save_path=checkpoint_dir,
        name_prefix='rl_model',
        save_replay_buffer=True,
        save_vecnormalize=True,
        verbose=1
    )
    return checkpoint_callback

# %%
# Parameters
env_id = 'HandManipulateEgg-v1'
total_timesteps = 5000000
checkpoint_dir = './checkpoints/'
video_folder = './videos/'

def make_env():
    return gym.make("HandManipulateEgg-v1", reward_type='dense', render_mode='rgb_array')

env = DummyVecEnv([make_env])
env = VecNormalize(env, norm_obs=True, norm_reward=True)
env = setup_video_recorder(env, video_folder=video_folder)

# PPO policy network config
policy_kwargs = dict(
    net_arch=dict(
        pi=[256, 256],
        vf=[256, 256]
    )
)

# Instantiate PPO model
model = PPO(
    'MultiInputPolicy',
    env,
    learning_rate=2e-4,
    clip_range=0.1,
    n_steps=2048,
    batch_size=64,
    policy_kwargs=policy_kwargs,
    verbose=1,
    tensorboard_log="./ppo_tensorboard/"
)

checkpoint_callback = setup_checkpoint_callback(checkpoint_dir=checkpoint_dir)

# Train and save
model.learn(total_timesteps=total_timesteps, callback=checkpoint_callback)
model.save(f"{checkpoint_dir}/final_model")

env.close()
# Out:
# Using cpu device
# Logging to ./ppo_tensorboard/PPO_27
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-0-to-step-200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-0-to-step-200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-0-to-step-200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-0-to-step-200.mp4
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    fps             | 280      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 264         |
# |    iterations           | 2           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.027855957 |
# |    clip_fraction        | 0.59        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -28.4       |
# |    explained_variance   | -0.237      |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0191     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0448     |
# |    std                  | 0.999       |
# |    value_loss           | 0.404       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 259         |
# |    iterations           | 3           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.032236904 |
# |    clip_fraction        | 0.602       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -28.4       |
# |    explained_variance   | 0.122       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0457     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.049      |
# |    std                  | 1           |
# |    value_loss           | 0.0807      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 256        |
# |    iterations           | 4          |
# |    time_elapsed         | 31         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.03276785 |
# |    clip_fraction        | 0.612      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -28.4      |
# |    explained_variance   | 0.544      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0524    |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0481    |
# |    std                  | 0.998      |
# |    value_loss           | 0.0651     |
# ----------------------------------------
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-10000-to-step-10200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-10000-to-step-10200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-10000-to-step-10200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-10000-to-step-10200.mp4
# -----------------------------------------
# | rollout/                |             |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 249         |
# |    iterations           | 5           |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.032566074 |
# |    clip_fraction        | 0.611       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -28.3       |
# |    explained_variance   | 0.399       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0433     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0483     |
# |    std                  | 0.997       |
# |    value_loss           | 0.0551      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 249        |
# |    iterations           | 6          |
# |    time_elapsed         | 49         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.03466177 |
# |    clip_fraction        | 0.623      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -28.3      |
# |    explained_variance   | 0.551      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0509    |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0484    |
# |    std                  | 0.998      |
# |    value_loss           | 0.0545     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 249        |
# |    iterations           | 7          |
# |    time_elapsed         | 57         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.03677677 |
# |    clip_fraction        | 0.634      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -28.3      |
# |    explained_variance   | 0.742      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0458    |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0501    |
# |    std                  | 0.998      |
# |    value_loss           | 0.0462     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 8           |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.040106483 |
# |    clip_fraction        | 0.639       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -28.3       |
# |    explained_variance   | 0.607       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0426     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.052      |
# |    std                  | 0.997       |
# |    value_loss           | 0.0573      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 9           |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.042872272 |
# |    clip_fraction        | 0.657       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -28.3       |
# |    explained_variance   | 0.712       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0576     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.05       |
# |    std                  | 0.997       |
# |    value_loss           | 0.0388      |
# -----------------------------------------
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-20000-to-step-20200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-20000-to-step-20200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-20000-to-step-20200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-20000-to-step-20200.mp4
# -----------------------------------------
# | rollout/                |             |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 10          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.040870685 |
# |    clip_fraction        | 0.64        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -28.3       |
# |    explained_variance   | 0.636       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0568     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0485     |
# |    std                  | 0.996       |
# |    value_loss           | 0.033       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 11          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.044699967 |
# |    clip_fraction        | 0.658       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -28.3       |
# |    explained_variance   | 0.786       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0576     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0509     |
# |    std                  | 0.994       |
# |    value_loss           | 0.0349      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 12          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.042264305 |
# |    clip_fraction        | 0.654       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -28.2       |
# |    explained_variance   | 0.663       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0591     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0505     |
# |    std                  | 0.992       |
# |    value_loss           | 0.0271      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 13          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.048608955 |
# |    clip_fraction        | 0.67        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -28.2       |
# |    explained_variance   | 0.655       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0569     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.051      |
# |    std                  | 0.991       |
# |    value_loss           | 0.0279      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 246         |
# |    iterations           | 14          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.047054227 |
# |    clip_fraction        | 0.655       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -28.2       |
# |    explained_variance   | 0.613       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0588     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.047      |
# |    std                  | 0.991       |
# |    value_loss           | 0.0262      |
# -----------------------------------------
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-30000-to-step-30200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-30000-to-step-30200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-30000-to-step-30200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-30000-to-step-30200.mp4
# -----------------------------------------
# | rollout/                |             |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 15          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.050246704 |
# |    clip_fraction        | 0.671       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -28.2       |
# |    explained_variance   | 0.813       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0703     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0505     |
# |    std                  | 0.99        |
# |    value_loss           | 0.0244      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 242        |
# |    iterations           | 16         |
# |    time_elapsed         | 134        |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.04721813 |
# |    clip_fraction        | 0.657      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -28.2      |
# |    explained_variance   | 0.837      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0627    |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0475    |
# |    std                  | 0.989      |
# |    value_loss           | 0.0225     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 242        |
# |    iterations           | 17         |
# |    time_elapsed         | 143        |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.04955555 |
# |    clip_fraction        | 0.676      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -28.2      |
# |    explained_variance   | 0.861      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.058     |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0506    |
# |    std                  | 0.989      |
# |    value_loss           | 0.0207     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 242        |
# |    iterations           | 18         |
# |    time_elapsed         | 151        |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.05380947 |
# |    clip_fraction        | 0.684      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -28.1      |
# |    explained_variance   | 0.889      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0611    |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0508    |
# |    std                  | 0.987      |
# |    value_loss           | 0.0168     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 19          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.053151645 |
# |    clip_fraction        | 0.676       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -28.1       |
# |    explained_variance   | 0.893       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0553     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0505     |
# |    std                  | 0.987       |
# |    value_loss           | 0.0188      |
# -----------------------------------------
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-40000-to-step-40200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-40000-to-step-40200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-40000-to-step-40200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-40000-to-step-40200.mp4
# -----------------------------------------
# | rollout/                |             |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 242         |
# |    iterations           | 20          |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.054029323 |
# |    clip_fraction        | 0.681       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -28.1       |
# |    explained_variance   | 0.915       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.06       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0508     |
# |    std                  | 0.987       |
# |    value_loss           | 0.016       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 242         |
# |    iterations           | 21          |
# |    time_elapsed         | 177         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.054167133 |
# |    clip_fraction        | 0.68        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -28.1       |
# |    explained_variance   | 0.917       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0624     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0499     |
# |    std                  | 0.987       |
# |    value_loss           | 0.0165      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 242        |
# |    iterations           | 22         |
# |    time_elapsed         | 185        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.05316603 |
# |    clip_fraction        | 0.69       |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -28.1      |
# |    explained_variance   | 0.934      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0645    |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0491    |
# |    std                  | 0.986      |
# |    value_loss           | 0.0157     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 242         |
# |    iterations           | 23          |
# |    time_elapsed         | 193         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.059927374 |
# |    clip_fraction        | 0.684       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -28.1       |
# |    explained_variance   | 0.863       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0642     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0507     |
# |    std                  | 0.987       |
# |    value_loss           | 0.015       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 243        |
# |    iterations           | 24         |
# |    time_elapsed         | 202        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.05659513 |
# |    clip_fraction        | 0.685      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -28.1      |
# |    explained_variance   | 0.922      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0557    |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0497    |
# |    std                  | 0.987      |
# |    value_loss           | 0.0137     |
# ----------------------------------------
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-50000-to-step-50200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-50000-to-step-50200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-50000-to-step-50200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-50000-to-step-50200.mp4
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 242        |
# |    iterations           | 25         |
# |    time_elapsed         | 211        |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.05555003 |
# |    clip_fraction        | 0.686      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -28.1      |
# |    explained_variance   | 0.941      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0646    |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0499    |
# |    std                  | 0.987      |
# |    value_loss           | 0.0117     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 242         |
# |    iterations           | 26          |
# |    time_elapsed         | 220         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.057063162 |
# |    clip_fraction        | 0.69        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -28.1       |
# |    explained_variance   | 0.887       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0599     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0489     |
# |    std                  | 0.988       |
# |    value_loss           | 0.0138      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 242         |
# |    iterations           | 27          |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.056520984 |
# |    clip_fraction        | 0.695       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -28.1       |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0651     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0503     |
# |    std                  | 0.986       |
# |    value_loss           | 0.0103      |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 243       |
# |    iterations           | 28        |
# |    time_elapsed         | 235       |
# |    total_timesteps      | 57344     |
# | train/                  |           |
# |    approx_kl            | 0.0648489 |
# |    clip_fraction        | 0.7       |
# |    clip_range           | 0.1       |
# |    entropy_loss         | -28.1     |
# |    explained_variance   | 0.931     |
# |    learning_rate        | 0.0002    |
# |    loss                 | -0.0572   |
# |    n_updates            | 270       |
# |    policy_gradient_loss | -0.0512   |
# |    std                  | 0.986     |
# |    value_loss           | 0.0112    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 29          |
# |    time_elapsed         | 243         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.056877855 |
# |    clip_fraction        | 0.689       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -28.1       |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.067      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0486     |
# |    std                  | 0.985       |
# |    value_loss           | 0.0105      |
# -----------------------------------------
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-60000-to-step-60200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-60000-to-step-60200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-60000-to-step-60200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-60000-to-step-60200.mp4
# -----------------------------------------
# | rollout/                |             |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 30          |
# |    time_elapsed         | 252         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.059850365 |
# |    clip_fraction        | 0.69        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -28.1       |
# |    explained_variance   | 0.926       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0619     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0492     |
# |    std                  | 0.983       |
# |    value_loss           | 0.00948     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 31          |
# |    time_elapsed         | 260         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.060888764 |
# |    clip_fraction        | 0.701       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -28         |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0671     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0507     |
# |    std                  | 0.981       |
# |    value_loss           | 0.0109      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 32          |
# |    time_elapsed         | 268         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.059907842 |
# |    clip_fraction        | 0.697       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -28         |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0618     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0476     |
# |    std                  | 0.979       |
# |    value_loss           | 0.00964     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 33          |
# |    time_elapsed         | 277         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.063576944 |
# |    clip_fraction        | 0.704       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -27.9       |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0566     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0504     |
# |    std                  | 0.977       |
# |    value_loss           | 0.009       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 243        |
# |    iterations           | 34         |
# |    time_elapsed         | 285        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.06357813 |
# |    clip_fraction        | 0.7        |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -27.9      |
# |    explained_variance   | 0.942      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0625    |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0489    |
# |    std                  | 0.976      |
# |    value_loss           | 0.00912    |
# ----------------------------------------
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-70000-to-step-70200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-70000-to-step-70200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-70000-to-step-70200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-70000-to-step-70200.mp4
# -----------------------------------------
# | rollout/                |             |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 35          |
# |    time_elapsed         | 294         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.067142986 |
# |    clip_fraction        | 0.712       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -27.9       |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0764     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0508     |
# |    std                  | 0.975       |
# |    value_loss           | 0.00849     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 242        |
# |    iterations           | 36         |
# |    time_elapsed         | 303        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.07311263 |
# |    clip_fraction        | 0.703      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -27.8      |
# |    explained_variance   | 0.883      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0647    |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.0484    |
# |    std                  | 0.971      |
# |    value_loss           | 0.0102     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 242        |
# |    iterations           | 37         |
# |    time_elapsed         | 312        |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.06925306 |
# |    clip_fraction        | 0.71       |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -27.8      |
# |    explained_variance   | 0.965      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0616    |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0511    |
# |    std                  | 0.97       |
# |    value_loss           | 0.00748    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 242        |
# |    iterations           | 38         |
# |    time_elapsed         | 320        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.06675018 |
# |    clip_fraction        | 0.708      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -27.7      |
# |    explained_variance   | 0.944      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0646    |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0494    |
# |    std                  | 0.967      |
# |    value_loss           | 0.00772    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 242        |
# |    iterations           | 39         |
# |    time_elapsed         | 329        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.06548672 |
# |    clip_fraction        | 0.703      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -27.7      |
# |    explained_variance   | 0.903      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0598    |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0464    |
# |    std                  | 0.966      |
# |    value_loss           | 0.00825    |
# ----------------------------------------
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-80000-to-step-80200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-80000-to-step-80200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-80000-to-step-80200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-80000-to-step-80200.mp4
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 241        |
# |    iterations           | 40         |
# |    time_elapsed         | 338        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.06572673 |
# |    clip_fraction        | 0.714      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -27.7      |
# |    explained_variance   | 0.947      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0651    |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0499    |
# |    std                  | 0.966      |
# |    value_loss           | 0.00826    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 241        |
# |    iterations           | 41         |
# |    time_elapsed         | 347        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.07411789 |
# |    clip_fraction        | 0.718      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -27.7      |
# |    explained_variance   | 0.903      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0644    |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0502    |
# |    std                  | 0.965      |
# |    value_loss           | 0.00761    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 241        |
# |    iterations           | 42         |
# |    time_elapsed         | 356        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.07211562 |
# |    clip_fraction        | 0.718      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -27.6      |
# |    explained_variance   | 0.901      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0593    |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.047     |
# |    std                  | 0.964      |
# |    value_loss           | 0.00759    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 241        |
# |    iterations           | 43         |
# |    time_elapsed         | 365        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.06711853 |
# |    clip_fraction        | 0.708      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -27.6      |
# |    explained_variance   | 0.933      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0571    |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.0469    |
# |    std                  | 0.962      |
# |    value_loss           | 0.0068     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 44          |
# |    time_elapsed         | 374         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.084732585 |
# |    clip_fraction        | 0.738       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -27.6       |
# |    explained_variance   | 0.926       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0666     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0488     |
# |    std                  | 0.961       |
# |    value_loss           | 0.0089      |
# -----------------------------------------
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-90000-to-step-90200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-90000-to-step-90200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-90000-to-step-90200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-90000-to-step-90200.mp4
# --------------------------------------
# | rollout/                |          |
# |    success_rate         | 0        |
# | time/                   |          |
# |    fps                  | 240      |
# |    iterations           | 45       |
# |    time_elapsed         | 383      |
# |    total_timesteps      | 92160    |
# | train/                  |          |
# |    approx_kl            | 0.070062 |
# |    clip_fraction        | 0.712    |
# |    clip_range           | 0.1      |
# |    entropy_loss         | -27.6    |
# |    explained_variance   | 0.937    |
# |    learning_rate        | 0.0002   |
# |    loss                 | -0.0634  |
# |    n_updates            | 440      |
# |    policy_gradient_loss | -0.0481  |
# |    std                  | 0.96     |
# |    value_loss           | 0.00688  |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 240        |
# |    iterations           | 46         |
# |    time_elapsed         | 391        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.07832924 |
# |    clip_fraction        | 0.712      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -27.6      |
# |    explained_variance   | 0.948      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0672    |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.048     |
# |    std                  | 0.96       |
# |    value_loss           | 0.00702    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 241        |
# |    iterations           | 47         |
# |    time_elapsed         | 398        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.07398103 |
# |    clip_fraction        | 0.722      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -27.6      |
# |    explained_variance   | 0.912      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0472    |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0489    |
# |    std                  | 0.959      |
# |    value_loss           | 0.0074     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 242        |
# |    iterations           | 48         |
# |    time_elapsed         | 406        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.09067528 |
# |    clip_fraction        | 0.736      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -27.5      |
# |    explained_variance   | 0.941      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0558    |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.0509    |
# |    std                  | 0.958      |
# |    value_loss           | 0.0076     |
# ----------------------------------------
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-100000-to-step-100200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-100000-to-step-100200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-100000-to-step-100200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-100000-to-step-100200.mp4
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 241        |
# |    iterations           | 49         |
# |    time_elapsed         | 415        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.08424823 |
# |    clip_fraction        | 0.722      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -27.5      |
# |    explained_variance   | 0.955      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0579    |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.0505    |
# ...
# | train/                  |            |
# |    approx_kl            | 0.08401208 |
# |    clip_fraction        | 0.725      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -27.4      |
# |    explained_variance   | 0.95       |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0715    |
# |    n_updates            | 540        |
# |    policy_gradient_loss | -0.05      |
# |    std                  | 0.95       |
# |    value_loss           | 0.00532    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 243        |
# |    iterations           | 56         |
# |    time_elapsed         | 471        |
# |    total_timesteps      | 114688     |
# | train/                  |            |
# |    approx_kl            | 0.08416227 |
# |    clip_fraction        | 0.704      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -27.3      |
# |    explained_variance   | 0.915      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0598    |
# |    n_updates            | 550        |
# |    policy_gradient_loss | -0.0424    |
# |    std                  | 0.948      |
# |    value_loss           | 0.00852    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 243        |
# |    iterations           | 57         |
# |    time_elapsed         | 478        |
# |    total_timesteps      | 116736     |
# | train/                  |            |
# |    approx_kl            | 0.08984361 |
# |    clip_fraction        | 0.739      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -27.3      |
# |    explained_variance   | 0.964      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0677    |
# |    n_updates            | 560        |
# |    policy_gradient_loss | -0.0499    |
# |    std                  | 0.948      |
# |    value_loss           | 0.00639    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 244        |
# |    iterations           | 58         |
# |    time_elapsed         | 486        |
# |    total_timesteps      | 118784     |
# | train/                  |            |
# |    approx_kl            | 0.08800282 |
# |    clip_fraction        | 0.74       |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -27.3      |
# |    explained_variance   | 0.928      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0651    |
# |    n_updates            | 570        |
# |    policy_gradient_loss | -0.0474    |
# |    std                  | 0.947      |
# |    value_loss           | 0.00586    |
# ----------------------------------------
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-120000-to-step-120200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-120000-to-step-120200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-120000-to-step-120200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-120000-to-step-120200.mp4
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 244        |
# |    iterations           | 59         |
# |    time_elapsed         | 493        |
# |    total_timesteps      | 120832     |
# | train/                  |            |
# |    approx_kl            | 0.08642259 |
# |    clip_fraction        | 0.736      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -27.3      |
# |    explained_variance   | 0.921      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0719    |
# |    n_updates            | 580        |
# |    policy_gradient_loss | -0.0488    |
# |    std                  | 0.946      |
# |    value_loss           | 0.00621    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 245        |
# |    iterations           | 60         |
# |    time_elapsed         | 499        |
# |    total_timesteps      | 122880     |
# | train/                  |            |
# |    approx_kl            | 0.09056613 |
# |    clip_fraction        | 0.732      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -27.3      |
# |    explained_variance   | 0.957      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0616    |
# |    n_updates            | 590        |
# |    policy_gradient_loss | -0.047     |
# |    std                  | 0.945      |
# |    value_loss           | 0.00583    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 246        |
# |    iterations           | 61         |
# |    time_elapsed         | 506        |
# |    total_timesteps      | 124928     |
# | train/                  |            |
# |    approx_kl            | 0.09113178 |
# |    clip_fraction        | 0.734      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -27.2      |
# |    explained_variance   | 0.914      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0617    |
# |    n_updates            | 600        |
# |    policy_gradient_loss | -0.0466    |
# |    std                  | 0.945      |
# |    value_loss           | 0.00563    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 247        |
# |    iterations           | 62         |
# |    time_elapsed         | 513        |
# |    total_timesteps      | 126976     |
# | train/                  |            |
# |    approx_kl            | 0.09467065 |
# |    clip_fraction        | 0.732      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -27.2      |
# |    explained_variance   | 0.949      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.06      |
# |    n_updates            | 610        |
# |    policy_gradient_loss | -0.0508    |
# |    std                  | 0.944      |
# |    value_loss           | 0.00622    |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 246       |
# |    iterations           | 63        |
# |    time_elapsed         | 522       |
# |    total_timesteps      | 129024    |
# | train/                  |           |
# |    approx_kl            | 0.1013813 |
# |    clip_fraction        | 0.744     |
# |    clip_range           | 0.1       |
# |    entropy_loss         | -27.2     |
# |    explained_variance   | 0.947     |
# |    learning_rate        | 0.0002    |
# |    loss                 | -0.0667   |
# |    n_updates            | 620       |
# |    policy_gradient_loss | -0.0501   |
# |    std                  | 0.943     |
# |    value_loss           | 0.00541   |
# ---------------------------------------
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-130000-to-step-130200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-130000-to-step-130200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-130000-to-step-130200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-130000-to-step-130200.mp4
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 246        |
# |    iterations           | 64         |
# |    time_elapsed         | 531        |
# |    total_timesteps      | 131072     |
# | train/                  |            |
# |    approx_kl            | 0.09264924 |
# |    clip_fraction        | 0.733      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -27.2      |
# |    explained_variance   | 0.966      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0712    |
# |    n_updates            | 630        |
# |    policy_gradient_loss | -0.0488    |
# |    std                  | 0.943      |
# |    value_loss           | 0.00601    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 246        |
# |    iterations           | 65         |
# |    time_elapsed         | 539        |
# |    total_timesteps      | 133120     |
# | train/                  |            |
# |    approx_kl            | 0.10374043 |
# |    clip_fraction        | 0.742      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -27.2      |
# |    explained_variance   | 0.966      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0542    |
# |    n_updates            | 640        |
# |    policy_gradient_loss | -0.0497    |
# |    std                  | 0.941      |
# |    value_loss           | 0.00583    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 247        |
# |    iterations           | 66         |
# |    time_elapsed         | 546        |
# |    total_timesteps      | 135168     |
# | train/                  |            |
# |    approx_kl            | 0.09366433 |
# |    clip_fraction        | 0.743      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -27.2      |
# |    explained_variance   | 0.964      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0685    |
# |    n_updates            | 650        |
# |    policy_gradient_loss | -0.0503    |
# |    std                  | 0.94       |
# |    value_loss           | 0.0046     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 247        |
# |    iterations           | 67         |
# |    time_elapsed         | 553        |
# |    total_timesteps      | 137216     |
# | train/                  |            |
# |    approx_kl            | 0.09786527 |
# |    clip_fraction        | 0.73       |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -27.1      |
# |    explained_variance   | 0.912      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0609    |
# |    n_updates            | 660        |
# |    policy_gradient_loss | -0.0446    |
# |    std                  | 0.938      |
# |    value_loss           | 0.00767    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 248         |
# |    iterations           | 68          |
# |    time_elapsed         | 561         |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.097558424 |
# |    clip_fraction        | 0.749       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -27.1       |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0662     |
# |    n_updates            | 670         |
# |    policy_gradient_loss | -0.0502     |
# |    std                  | 0.937       |
# |    value_loss           | 0.00562     |
# -----------------------------------------
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-140000-to-step-140200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-140000-to-step-140200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-140000-to-step-140200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-140000-to-step-140200.mp4
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 248        |
# |    iterations           | 69         |
# |    time_elapsed         | 569        |
# |    total_timesteps      | 141312     |
# | train/                  |            |
# |    approx_kl            | 0.09599351 |
# |    clip_fraction        | 0.746      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -27.1      |
# |    explained_variance   | 0.971      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0585    |
# |    n_updates            | 680        |
# |    policy_gradient_loss | -0.0479    |
# |    std                  | 0.936      |
# |    value_loss           | 0.00449    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 248        |
# |    iterations           | 70         |
# |    time_elapsed         | 576        |
# |    total_timesteps      | 143360     |
# | train/                  |            |
# |    approx_kl            | 0.09873855 |
# |    clip_fraction        | 0.754      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -27.1      |
# |    explained_variance   | 0.965      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0574    |
# |    n_updates            | 690        |
# |    policy_gradient_loss | -0.0492    |
# |    std                  | 0.936      |
# |    value_loss           | 0.005      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 249         |
# |    iterations           | 71          |
# |    time_elapsed         | 583         |
# |    total_timesteps      | 145408      |
# | train/                  |             |
# |    approx_kl            | 0.100476265 |
# |    clip_fraction        | 0.745       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -27.1       |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0624     |
# |    n_updates            | 700         |
# |    policy_gradient_loss | -0.0488     |
# |    std                  | 0.936       |
# |    value_loss           | 0.00485     |
# -----------------------------------------
