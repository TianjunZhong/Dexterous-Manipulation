# %%
import gymnasium as gym
import gymnasium_robotics
from stable_baselines3 import SAC
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.vec_env import SubprocVecEnv, VecVideoRecorder, DummyVecEnv
from stable_baselines3.common.vec_env import VecNormalize

# %%
def setup_video_recorder(env, video_folder='videos/', record_freq=10000, video_length=200):
    """
    Wrap the environment with a video recorder to capture agent performances.
    """
    env = VecVideoRecorder(
        env,
        video_folder,
        record_video_trigger=lambda step: step % record_freq == 0,
        video_length=video_length,
        name_prefix='rl-agent'
    )
    return env

def setup_checkpoint_callback(checkpoint_dir='checkpoints/', save_freq=1000):
    """
    Create a callback that saves the model at regular intervals.
    """
    checkpoint_callback = CheckpointCallback(
        save_freq=save_freq,
        save_path=checkpoint_dir,
        name_prefix='rl_model',
        save_replay_buffer=True,
        save_vecnormalize=True,
        verbose=1
    )
    return checkpoint_callback

# %%
# Parameters
env_id = 'HandManipulateEgg-v1'
total_timesteps = 5000000
checkpoint_dir = './checkpoints/'
video_folder = './videos/'

def make_env():
    return gym.make("HandManipulateEgg-v1", reward_type='dense', render_mode='rgb_array')

env = DummyVecEnv([make_env])
env = VecNormalize(env, norm_obs=True, norm_reward=True)
env = setup_video_recorder(env, video_folder=video_folder)

# PPO policy network config
policy_kwargs = dict(
    net_arch=[256, 256]
)

# Instantiate PPO model
model = SAC(
    'MultiInputPolicy',
    env,
    learning_rate=1e-4,
    batch_size=128,
    policy_kwargs=policy_kwargs,
    verbose=1,
    tensorboard_log="./sac_tensorboard/",
    device='cuda'
)

checkpoint_callback = setup_checkpoint_callback(checkpoint_dir=checkpoint_dir)

# Train and save
model.learn(total_timesteps=total_timesteps, callback=checkpoint_callback)
model.save(f"{checkpoint_dir}/final_model")

env.close()
# Out:
# Using cpu device
# Logging to ./sac_tensorboard/SAC_2
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-0-to-step-200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-0-to-step-200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-0-to-step-200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-0-to-step-200.mp4
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 78       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 400      |
# | train/             |          |
# |    actor_loss      | -30.3    |
# |    critic_loss     | 3.45     |
# |    ent_coef        | 0.971    |
# |    ent_coef_loss   | -1       |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 299      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 79       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 800      |
# | train/             |          |
# |    actor_loss      | -46.6    |
# |    critic_loss     | 2.73     |
# |    ent_coef        | 0.933    |
# |    ent_coef_loss   | -2.3     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 699      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 73       |
# |    time_elapsed    | 16       |
# |    total_timesteps | 1200     |
# | train/             |          |
# |    actor_loss      | -65.1    |
# |    critic_loss     | 2.44     |
# |    ent_coef        | 0.896    |
# |    ent_coef_loss   | -3.59    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 74       |
# |    time_elapsed    | 21       |
# |    total_timesteps | 1600     |
# | train/             |          |
# |    actor_loss      | -82      |
# |    critic_loss     | 4.2      |
# |    ent_coef        | 0.862    |
# |    ent_coef_loss   | -4.84    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 70       |
# |    time_elapsed    | 28       |
# |    total_timesteps | 2000     |
# | train/             |          |
# |    actor_loss      | -97.9    |
# |    critic_loss     | 7.52     |
# |    ent_coef        | 0.828    |
# |    ent_coef_loss   | -6.07    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 71       |
# |    time_elapsed    | 33       |
# |    total_timesteps | 2400     |
# | train/             |          |
# |    actor_loss      | -117     |
# |    critic_loss     | 7.63     |
# |    ent_coef        | 0.796    |
# |    ent_coef_loss   | -7.26    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 2299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 72       |
# |    time_elapsed    | 38       |
# |    total_timesteps | 2800     |
# | train/             |          |
# |    actor_loss      | -131     |
# |    critic_loss     | 8.07     |
# |    ent_coef        | 0.766    |
# |    ent_coef_loss   | -8.32    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 2699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 71       |
# |    time_elapsed    | 45       |
# |    total_timesteps | 3200     |
# | train/             |          |
# |    actor_loss      | -147     |
# |    critic_loss     | 8.21     |
# |    ent_coef        | 0.737    |
# |    ent_coef_loss   | -9.51    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 3099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 71       |
# |    time_elapsed    | 50       |
# |    total_timesteps | 3600     |
# | train/             |          |
# |    actor_loss      | -159     |
# |    critic_loss     | 8.93     |
# |    ent_coef        | 0.709    |
# |    ent_coef_loss   | -10.5    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 3499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 70       |
# |    time_elapsed    | 56       |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | -171     |
# |    critic_loss     | 13.3     |
# |    ent_coef        | 0.682    |
# |    ent_coef_loss   | -11.4    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 3899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 71       |
# |    time_elapsed    | 61       |
# |    total_timesteps | 4400     |
# | train/             |          |
# |    actor_loss      | -182     |
# |    critic_loss     | 9.31     |
# |    ent_coef        | 0.656    |
# |    ent_coef_loss   | -12.5    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 4299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 71       |
# |    time_elapsed    | 66       |
# |    total_timesteps | 4800     |
# | train/             |          |
# |    actor_loss      | -196     |
# |    critic_loss     | 19.8     |
# |    ent_coef        | 0.631    |
# |    ent_coef_loss   | -13.7    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 4699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 71       |
# |    time_elapsed    | 73       |
# |    total_timesteps | 5200     |
# | train/             |          |
# |    actor_loss      | -203     |
# |    critic_loss     | 13.2     |
# |    ent_coef        | 0.607    |
# |    ent_coef_loss   | -14.4    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 5099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 71       |
# |    time_elapsed    | 78       |
# |    total_timesteps | 5600     |
# | train/             |          |
# |    actor_loss      | -213     |
# |    critic_loss     | 9.74     |
# |    ent_coef        | 0.584    |
# |    ent_coef_loss   | -15.1    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 5499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 70       |
# |    time_elapsed    | 84       |
# |    total_timesteps | 6000     |
# | train/             |          |
# |    actor_loss      | -223     |
# |    critic_loss     | 11.9     |
# |    ent_coef        | 0.562    |
# |    ent_coef_loss   | -15.8    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 5899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 70       |
# |    time_elapsed    | 90       |
# |    total_timesteps | 6400     |
# | train/             |          |
# |    actor_loss      | -231     |
# |    critic_loss     | 17.1     |
# |    ent_coef        | 0.541    |
# |    ent_coef_loss   | -17      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 6299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 71       |
# |    time_elapsed    | 95       |
# |    total_timesteps | 6800     |
# | train/             |          |
# |    actor_loss      | -236     |
# |    critic_loss     | 16.6     |
# |    ent_coef        | 0.521    |
# |    ent_coef_loss   | -17.6    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 6699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 71       |
# |    time_elapsed    | 101      |
# |    total_timesteps | 7200     |
# | train/             |          |
# |    actor_loss      | -245     |
# |    critic_loss     | 13.4     |
# |    ent_coef        | 0.501    |
# |    ent_coef_loss   | -18      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 7099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 71       |
# |    time_elapsed    | 106      |
# |    total_timesteps | 7600     |
# | train/             |          |
# |    actor_loss      | -250     |
# |    critic_loss     | 17       |
# |    ent_coef        | 0.482    |
# |    ent_coef_loss   | -19.2    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 7499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 71       |
# |    time_elapsed    | 112      |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | -255     |
# |    critic_loss     | 17.7     |
# |    ent_coef        | 0.464    |
# |    ent_coef_loss   | -19.9    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 7899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 71       |
# |    time_elapsed    | 117      |
# |    total_timesteps | 8400     |
# | train/             |          |
# |    actor_loss      | -260     |
# |    critic_loss     | 18.8     |
# |    ent_coef        | 0.447    |
# |    ent_coef_loss   | -20.7    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 8299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 71       |
# |    time_elapsed    | 122      |
# |    total_timesteps | 8800     |
# | train/             |          |
# |    actor_loss      | -270     |
# |    critic_loss     | 14.4     |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | -20.6    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 8699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 71       |
# |    time_elapsed    | 129      |
# |    total_timesteps | 9200     |
# | train/             |          |
# |    actor_loss      | -271     |
# |    critic_loss     | 21.6     |
# |    ent_coef        | 0.414    |
# |    ent_coef_loss   | -21.3    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 9099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 71       |
# |    time_elapsed    | 134      |
# |    total_timesteps | 9600     |
# | train/             |          |
# |    actor_loss      | -275     |
# |    critic_loss     | 18.4     |
# |    ent_coef        | 0.398    |
# |    ent_coef_loss   | -21.9    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 9499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 71       |
# |    time_elapsed    | 140      |
# |    total_timesteps | 10000    |
# | train/             |          |
# |    actor_loss      | -285     |
# |    critic_loss     | 19.8     |
# |    ent_coef        | 0.383    |
# |    ent_coef_loss   | -21.7    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 9899     |
# ---------------------------------
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-10000-to-step-10200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-10000-to-step-10200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-10000-to-step-10200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-10000-to-step-10200.mp4
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 71       |
# |    time_elapsed    | 146      |
# |    total_timesteps | 10400    |
# | train/             |          |
# |    actor_loss      | -285     |
# |    critic_loss     | 16       |
# |    ent_coef        | 0.369    |
# |    ent_coef_loss   | -22.3    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 10299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 71       |
# |    time_elapsed    | 151      |
# |    total_timesteps | 10800    |
# | train/             |          |
# |    actor_loss      | -290     |
# |    critic_loss     | 13.6     |
# |    ent_coef        | 0.355    |
# |    ent_coef_loss   | -24      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 10699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 71       |
# |    time_elapsed    | 157      |
# |    total_timesteps | 11200    |
# | train/             |          |
# |    actor_loss      | -292     |
# |    critic_loss     | 21.8     |
# |    ent_coef        | 0.341    |
# |    ent_coef_loss   | -25.7    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 11099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 71       |
# |    time_elapsed    | 162      |
# |    total_timesteps | 11600    |
# | train/             |          |
# |    actor_loss      | -295     |
# |    critic_loss     | 15       |
# |    ent_coef        | 0.328    |
# |    ent_coef_loss   | -24.6    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 11499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 71       |
# |    time_elapsed    | 168      |
# |    total_timesteps | 12000    |
# | train/             |          |
# |    actor_loss      | -297     |
# |    critic_loss     | 17.8     |
# |    ent_coef        | 0.316    |
# |    ent_coef_loss   | -24.9    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 11899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 71       |
# |    time_elapsed    | 173      |
# |    total_timesteps | 12400    |
# | train/             |          |
# |    actor_loss      | -297     |
# |    critic_loss     | 18.7     |
# |    ent_coef        | 0.304    |
# |    ent_coef_loss   | -26.6    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 12299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 71       |
# |    time_elapsed    | 178      |
# |    total_timesteps | 12800    |
# | train/             |          |
# |    actor_loss      | -303     |
# |    critic_loss     | 16.4     |
# |    ent_coef        | 0.293    |
# |    ent_coef_loss   | -26.7    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 12699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 71       |
# |    time_elapsed    | 184      |
# |    total_timesteps | 13200    |
# | train/             |          |
# |    actor_loss      | -301     |
# |    critic_loss     | 15.8     |
# |    ent_coef        | 0.282    |
# |    ent_coef_loss   | -27.5    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 13099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 71       |
# |    time_elapsed    | 189      |
# |    total_timesteps | 13600    |
# | train/             |          |
# |    actor_loss      | -301     |
# |    critic_loss     | 15.1     |
# |    ent_coef        | 0.271    |
# |    ent_coef_loss   | -26.5    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 13499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 71       |
# |    time_elapsed    | 195      |
# |    total_timesteps | 14000    |
# | train/             |          |
# |    actor_loss      | -302     |
# |    critic_loss     | 14.7     |
# |    ent_coef        | 0.261    |
# |    ent_coef_loss   | -27.4    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 13899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 71       |
# |    time_elapsed    | 200      |
# |    total_timesteps | 14400    |
# | train/             |          |
# |    actor_loss      | -301     |
# |    critic_loss     | 12.5     |
# |    ent_coef        | 0.251    |
# |    ent_coef_loss   | -25.6    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 14299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 71       |
# |    time_elapsed    | 205      |
# |    total_timesteps | 14800    |
# | train/             |          |
# |    actor_loss      | -300     |
# |    critic_loss     | 14.8     |
# |    ent_coef        | 0.242    |
# |    ent_coef_loss   | -24.8    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 14699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 71       |
# |    time_elapsed    | 211      |
# |    total_timesteps | 15200    |
# | train/             |          |
# |    actor_loss      | -304     |
# |    critic_loss     | 15.8     |
# |    ent_coef        | 0.233    |
# |    ent_coef_loss   | -25.3    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 15099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 71       |
# |    time_elapsed    | 217      |
# |    total_timesteps | 15600    |
# | train/             |          |
# |    actor_loss      | -302     |
# |    critic_loss     | 12.3     |
# |    ent_coef        | 0.224    |
# |    ent_coef_loss   | -28.2    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 15499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 71       |
# |    time_elapsed    | 224      |
# |    total_timesteps | 16000    |
# | train/             |          |
# |    actor_loss      | -307     |
# |    critic_loss     | 10.2     |
# |    ent_coef        | 0.216    |
# |    ent_coef_loss   | -28      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 15899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 71       |
# |    time_elapsed    | 230      |
# |    total_timesteps | 16400    |
# | train/             |          |
# |    actor_loss      | -308     |
# |    critic_loss     | 13.2     |
# |    ent_coef        | 0.208    |
# |    ent_coef_loss   | -28.7    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 16299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 71       |
# |    time_elapsed    | 235      |
# |    total_timesteps | 16800    |
# | train/             |          |
# |    actor_loss      | -310     |
# |    critic_loss     | 9.62     |
# |    ent_coef        | 0.2      |
# |    ent_coef_loss   | -25.4    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 16699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 71       |
# |    time_elapsed    | 241      |
# |    total_timesteps | 17200    |
# | train/             |          |
# |    actor_loss      | -313     |
# |    critic_loss     | 12.4     |
# |    ent_coef        | 0.193    |
# |    ent_coef_loss   | -29.7    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 17099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 71       |
# |    time_elapsed    | 246      |
# |    total_timesteps | 17600    |
# | train/             |          |
# |    actor_loss      | -308     |
# |    critic_loss     | 12.1     |
# |    ent_coef        | 0.186    |
# |    ent_coef_loss   | -27.7    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 17499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 71       |
# |    time_elapsed    | 252      |
# |    total_timesteps | 18000    |
# | train/             |          |
# |    actor_loss      | -306     |
# |    critic_loss     | 11.9     |
# |    ent_coef        | 0.179    |
# |    ent_coef_loss   | -26.2    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 17899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 71       |
# |    time_elapsed    | 257      |
# |    total_timesteps | 18400    |
# | train/             |          |
# |    actor_loss      | -305     |
# |    critic_loss     | 10.5     |
# |    ent_coef        | 0.172    |
# |    ent_coef_loss   | -26.5    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 18299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 71       |
# |    time_elapsed    | 262      |
# |    total_timesteps | 18800    |
# | train/             |          |
# |    actor_loss      | -307     |
# |    critic_loss     | 11       |
# |    ent_coef        | 0.166    |
# |    ent_coef_loss   | -28.5    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 18699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 71       |
# |    time_elapsed    | 268      |
# |    total_timesteps | 19200    |
# | train/             |          |
# |    actor_loss      | -303     |
# |    critic_loss     | 11.6     |
# |    ent_coef        | 0.16     |
# |    ent_coef_loss   | -28.7    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 19099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 71       |
# |    time_elapsed    | 273      |
# |    total_timesteps | 19600    |
# | train/             |          |
# |    actor_loss      | -303     |
# |    critic_loss     | 12.1     |
# |    ent_coef        | 0.154    |
# |    ent_coef_loss   | -27.5    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 19499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 71       |
# |    time_elapsed    | 279      |
# |    total_timesteps | 20000    |
# | train/             |          |
# |    actor_loss      | -303     |
# |    critic_loss     | 9.14     |
# |    ent_coef        | 0.148    |
# |    ent_coef_loss   | -28.4    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 19899    |
# ---------------------------------
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-20000-to-step-20200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-20000-to-step-20200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-20000-to-step-20200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-20000-to-step-20200.mp4
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 71       |
# |    time_elapsed    | 285      |
# |    total_timesteps | 20400    |
# | train/             |          |
# |    actor_loss      | -307     |
# |    critic_loss     | 10.7     |
# |    ent_coef        | 0.143    |
# |    ent_coef_loss   | -24.7    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 20299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 71       |
# |    time_elapsed    | 290      |
# |    total_timesteps | 20800    |
# | train/             |          |
# |    actor_loss      | -302     |
# |    critic_loss     | 9.3      |
# |    ent_coef        | 0.137    |
# |    ent_coef_loss   | -26      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 20699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 71       |
# |    time_elapsed    | 297      |
# |    total_timesteps | 21200    |
# | train/             |          |
# |    actor_loss      | -301     |
# |    critic_loss     | 9.12     |
# |    ent_coef        | 0.133    |
# |    ent_coef_loss   | -25.9    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 21099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 71       |
# |    time_elapsed    | 302      |
# |    total_timesteps | 21600    |
# | train/             |          |
# |    actor_loss      | -302     |
# |    critic_loss     | 8.28     |
# |    ent_coef        | 0.128    |
# |    ent_coef_loss   | -24.4    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 21499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 71       |
# |    time_elapsed    | 308      |
# |    total_timesteps | 22000    |
# | train/             |          |
# |    actor_loss      | -299     |
# |    critic_loss     | 8.37     |
# |    ent_coef        | 0.123    |
# |    ent_coef_loss   | -22.8    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 21899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 71       |
# |    time_elapsed    | 313      |
# |    total_timesteps | 22400    |
# | train/             |          |
# |    actor_loss      | -299     |
# |    critic_loss     | 11.1     |
# |    ent_coef        | 0.119    |
# |    ent_coef_loss   | -25.7    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 22299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 71       |
# |    time_elapsed    | 319      |
# |    total_timesteps | 22800    |
# | train/             |          |
# |    actor_loss      | -300     |
# |    critic_loss     | 10.1     |
# |    ent_coef        | 0.115    |
# |    ent_coef_loss   | -21.8    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 22699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 71       |
# |    time_elapsed    | 325      |
# |    total_timesteps | 23200    |
# | train/             |          |
# |    actor_loss      | -298     |
# |    critic_loss     | 8.52     |
# |    ent_coef        | 0.11     |
# |    ent_coef_loss   | -23.3    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 23099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 71       |
# |    time_elapsed    | 331      |
# |    total_timesteps | 23600    |
# | train/             |          |
# |    actor_loss      | -301     |
# |    critic_loss     | 6.64     |
# |    ent_coef        | 0.106    |
# |    ent_coef_loss   | -22      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 23499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 71       |
# |    time_elapsed    | 336      |
# |    total_timesteps | 24000    |
# | train/             |          |
# |    actor_loss      | -295     |
# |    critic_loss     | 9.1      |
# |    ent_coef        | 0.103    |
# |    ent_coef_loss   | -20.7    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 23899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 71       |
# |    time_elapsed    | 341      |
# |    total_timesteps | 24400    |
# | train/             |          |
# |    actor_loss      | -299     |
# |    critic_loss     | 9.49     |
# |    ent_coef        | 0.0994   |
# |    ent_coef_loss   | -22.5    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 24299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 71       |
# |    time_elapsed    | 346      |
# |    total_timesteps | 24800    |
# | train/             |          |
# |    actor_loss      | -292     |
# |    critic_loss     | 7.52     |
# |    ent_coef        | 0.0961   |
# |    ent_coef_loss   | -15.7    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 24699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 71       |
# |    time_elapsed    | 352      |
# |    total_timesteps | 25200    |
# | train/             |          |
# |    actor_loss      | -295     |
# |    critic_loss     | 7.54     |
# |    ent_coef        | 0.0929   |
# |    ent_coef_loss   | -19.8    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 25099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 71       |
# |    time_elapsed    | 358      |
# |    total_timesteps | 25600    |
# | train/             |          |
# |    actor_loss      | -289     |
# |    critic_loss     | 8.23     |
# |    ent_coef        | 0.0898   |
# |    ent_coef_loss   | -18.8    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 25499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 71       |
# |    time_elapsed    | 364      |
# |    total_timesteps | 26000    |
# | train/             |          |
# |    actor_loss      | -283     |
# |    critic_loss     | 7.61     |
# |    ent_coef        | 0.0869   |
# |    ent_coef_loss   | -15.2    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 25899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 71       |
# |    time_elapsed    | 369      |
# |    total_timesteps | 26400    |
# | train/             |          |
# |    actor_loss      | -290     |
# |    critic_loss     | 8.78     |
# |    ent_coef        | 0.0843   |
# |    ent_coef_loss   | -16.5    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 26299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 71       |
# |    time_elapsed    | 374      |
# |    total_timesteps | 26800    |
# | train/             |          |
# |    actor_loss      | -284     |
# |    critic_loss     | 6.41     |
# |    ent_coef        | 0.0814   |
# |    ent_coef_loss   | -16      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 26699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 71       |
# |    time_elapsed    | 380      |
# |    total_timesteps | 27200    |
# | train/             |          |
# |    actor_loss      | -285     |
# |    critic_loss     | 8.63     |
# |    ent_coef        | 0.0785   |
# |    ent_coef_loss   | -21.7    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 27099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 71       |
# |    time_elapsed    | 386      |
# |    total_timesteps | 27600    |
# | train/             |          |
# |    actor_loss      | -286     |
# |    critic_loss     | 8.16     |
# |    ent_coef        | 0.0757   |
# |    ent_coef_loss   | -13      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 27499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 71       |
# |    time_elapsed    | 392      |
# |    total_timesteps | 28000    |
# | train/             |          |
# |    actor_loss      | -285     |
# |    critic_loss     | 7.78     |
# |    ent_coef        | 0.0734   |
# |    ent_coef_loss   | -9.63    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 27899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 71       |
# |    time_elapsed    | 397      |
# |    total_timesteps | 28400    |
# | train/             |          |
# |    actor_loss      | -282     |
# |    critic_loss     | 6.03     |
# |    ent_coef        | 0.0714   |
# |    ent_coef_loss   | -10.6    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 28299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 71       |
# |    time_elapsed    | 402      |
# |    total_timesteps | 28800    |
# | train/             |          |
# |    actor_loss      | -277     |
# |    critic_loss     | 8.15     |
# |    ent_coef        | 0.0696   |
# |    ent_coef_loss   | -10.9    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 28699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 71       |
# |    time_elapsed    | 408      |
# |    total_timesteps | 29200    |
# | train/             |          |
# |    actor_loss      | -279     |
# |    critic_loss     | 5.33     |
# |    ent_coef        | 0.0676   |
# |    ent_coef_loss   | -6.5     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 29099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 71       |
# |    time_elapsed    | 414      |
# |    total_timesteps | 29600    |
# | train/             |          |
# |    actor_loss      | -282     |
# |    critic_loss     | 5.98     |
# |    ent_coef        | 0.0657   |
# |    ent_coef_loss   | -7.24    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 29499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 71       |
# |    time_elapsed    | 420      |
# |    total_timesteps | 30000    |
# | train/             |          |
# |    actor_loss      | -277     |
# |    critic_loss     | 5.22     |
# |    ent_coef        | 0.064    |
# |    ent_coef_loss   | -2.82    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 29899    |
# ---------------------------------
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-30000-to-step-30200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-30000-to-step-30200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-30000-to-step-30200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-30000-to-step-30200.mp4
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 71       |
# |    time_elapsed    | 426      |
# |    total_timesteps | 30400    |
# | train/             |          |
# |    actor_loss      | -278     |
# |    critic_loss     | 7.21     |
# |    ent_coef        | 0.0624   |
# |    ent_coef_loss   | -5.83    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 30299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 71       |
# |    time_elapsed    | 431      |
# |    total_timesteps | 30800    |
# | train/             |          |
# |    actor_loss      | -273     |
# |    critic_loss     | 5.83     |
# |    ent_coef        | 0.0605   |
# |    ent_coef_loss   | -8.48    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 30699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 71       |
# |    time_elapsed    | 437      |
# |    total_timesteps | 31200    |
# | train/             |          |
# |    actor_loss      | -271     |
# |    critic_loss     | 7.22     |
# |    ent_coef        | 0.0587   |
# |    ent_coef_loss   | -9.29    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 31099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 71       |
# |    time_elapsed    | 443      |
# |    total_timesteps | 31600    |
# | train/             |          |
# |    actor_loss      | -273     |
# |    critic_loss     | 5.41     |
# |    ent_coef        | 0.057    |
# |    ent_coef_loss   | -5.19    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 31499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 71       |
# |    time_elapsed    | 448      |
# |    total_timesteps | 32000    |
# | train/             |          |
# |    actor_loss      | -275     |
# |    critic_loss     | 4.07     |
# |    ent_coef        | 0.0557   |
# |    ent_coef_loss   | -3.07    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 31899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 71       |
# |    time_elapsed    | 453      |
# |    total_timesteps | 32400    |
# | train/             |          |
# |    actor_loss      | -270     |
# |    critic_loss     | 5.5      |
# |    ent_coef        | 0.0548   |
# |    ent_coef_loss   | -4.28    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 32299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 71       |
# |    time_elapsed    | 458      |
# |    total_timesteps | 32800    |
# | train/             |          |
# |    actor_loss      | -267     |
# |    critic_loss     | 5.5      |
# |    ent_coef        | 0.054    |
# |    ent_coef_loss   | -3.13    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 32699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 71       |
# |    time_elapsed    | 464      |
# |    total_timesteps | 33200    |
# | train/             |          |
# |    actor_loss      | -268     |
# |    critic_loss     | 5.75     |
# |    ent_coef        | 0.0528   |
# |    ent_coef_loss   | -1.84    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 33099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 71       |
# |    time_elapsed    | 469      |
# |    total_timesteps | 33600    |
# | train/             |          |
# |    actor_loss      | -266     |
# |    critic_loss     | 4.48     |
# |    ent_coef        | 0.0519   |
# |    ent_coef_loss   | -1.42    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 33499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# ...
# |    critic_loss     | 0.17     |
# |    ent_coef        | 0.00508  |
# |    ent_coef_loss   | -4.1     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 86699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 872      |
# |    fps             | 70       |
# |    time_elapsed    | 1234     |
# |    total_timesteps | 87200    |
# | train/             |          |
# |    actor_loss      | -65.3    |
# |    critic_loss     | 0.183    |
# |    ent_coef        | 0.00495  |
# |    ent_coef_loss   | -8.04    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 87099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 876      |
# |    fps             | 70       |
# |    time_elapsed    | 1239     |
# |    total_timesteps | 87600    |
# | train/             |          |
# |    actor_loss      | -63.9    |
# |    critic_loss     | 0.168    |
# |    ent_coef        | 0.00488  |
# |    ent_coef_loss   | 2.49     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 87499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 880      |
# |    fps             | 70       |
# |    time_elapsed    | 1245     |
# |    total_timesteps | 88000    |
# | train/             |          |
# |    actor_loss      | -63.2    |
# |    critic_loss     | 0.119    |
# |    ent_coef        | 0.00477  |
# |    ent_coef_loss   | 7.93     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 87899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 884      |
# |    fps             | 70       |
# |    time_elapsed    | 1251     |
# |    total_timesteps | 88400    |
# | train/             |          |
# |    actor_loss      | -62.1    |
# |    critic_loss     | 0.137    |
# |    ent_coef        | 0.0047   |
# |    ent_coef_loss   | 3.96     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 88299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 888      |
# |    fps             | 70       |
# |    time_elapsed    | 1256     |
# |    total_timesteps | 88800    |
# | train/             |          |
# |    actor_loss      | -62.5    |
# |    critic_loss     | 0.138    |
# |    ent_coef        | 0.0046   |
# |    ent_coef_loss   | -9.35    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 88699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 892      |
# |    fps             | 70       |
# |    time_elapsed    | 1262     |
# |    total_timesteps | 89200    |
# | train/             |          |
# |    actor_loss      | -59.7    |
# |    critic_loss     | 0.109    |
# |    ent_coef        | 0.0045   |
# |    ent_coef_loss   | -4.37    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 89099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 896      |
# |    fps             | 70       |
# |    time_elapsed    | 1267     |
# |    total_timesteps | 89600    |
# | train/             |          |
# |    actor_loss      | -60.3    |
# |    critic_loss     | 0.111    |
# |    ent_coef        | 0.00439  |
# |    ent_coef_loss   | 1.88     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 89499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 900      |
# |    fps             | 70       |
# |    time_elapsed    | 1273     |
# |    total_timesteps | 90000    |
# | train/             |          |
# |    actor_loss      | -58.9    |
# |    critic_loss     | 0.107    |
# |    ent_coef        | 0.00432  |
# |    ent_coef_loss   | -5.98    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 89899    |
# ---------------------------------
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-90000-to-step-90200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-90000-to-step-90200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-90000-to-step-90200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-90000-to-step-90200.mp4
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 904      |
# |    fps             | 70       |
# |    time_elapsed    | 1279     |
# |    total_timesteps | 90400    |
# | train/             |          |
# |    actor_loss      | -58.9    |
# |    critic_loss     | 0.109    |
# |    ent_coef        | 0.00426  |
# |    ent_coef_loss   | 0.494    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 90299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 908      |
# |    fps             | 70       |
# |    time_elapsed    | 1284     |
# |    total_timesteps | 90800    |
# | train/             |          |
# |    actor_loss      | -58      |
# |    critic_loss     | 0.117    |
# |    ent_coef        | 0.00422  |
# |    ent_coef_loss   | -0.665   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 90699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 912      |
# |    fps             | 70       |
# |    time_elapsed    | 1290     |
# |    total_timesteps | 91200    |
# | train/             |          |
# |    actor_loss      | -56.4    |
# |    critic_loss     | 0.123    |
# |    ent_coef        | 0.0042   |
# |    ent_coef_loss   | -7.48    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 91099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 916      |
# |    fps             | 70       |
# |    time_elapsed    | 1295     |
# |    total_timesteps | 91600    |
# | train/             |          |
# |    actor_loss      | -55.5    |
# |    critic_loss     | 0.105    |
# |    ent_coef        | 0.00409  |
# |    ent_coef_loss   | -6.76    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 91499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 920      |
# |    fps             | 70       |
# |    time_elapsed    | 1301     |
# |    total_timesteps | 92000    |
# | train/             |          |
# |    actor_loss      | -54.9    |
# |    critic_loss     | 0.091    |
# |    ent_coef        | 0.00401  |
# |    ent_coef_loss   | 2.03     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 91899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 924      |
# |    fps             | 70       |
# |    time_elapsed    | 1307     |
# |    total_timesteps | 92400    |
# | train/             |          |
# |    actor_loss      | -54.7    |
# |    critic_loss     | 0.126    |
# |    ent_coef        | 0.00395  |
# |    ent_coef_loss   | 0.611    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 92299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 928      |
# |    fps             | 70       |
# |    time_elapsed    | 1312     |
# |    total_timesteps | 92800    |
# | train/             |          |
# |    actor_loss      | -54.2    |
# |    critic_loss     | 0.0818   |
# |    ent_coef        | 0.00387  |
# |    ent_coef_loss   | 2.73     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 92699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 932      |
# |    fps             | 70       |
# |    time_elapsed    | 1318     |
# |    total_timesteps | 93200    |
# | train/             |          |
# |    actor_loss      | -52.9    |
# |    critic_loss     | 0.119    |
# |    ent_coef        | 0.00381  |
# |    ent_coef_loss   | -6.72    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 93099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 936      |
# |    fps             | 70       |
# |    time_elapsed    | 1323     |
# |    total_timesteps | 93600    |
# | train/             |          |
# |    actor_loss      | -52.7    |
# |    critic_loss     | 0.0869   |
# |    ent_coef        | 0.00373  |
# |    ent_coef_loss   | -2.78    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 93499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 940      |
# |    fps             | 70       |
# |    time_elapsed    | 1329     |
# |    total_timesteps | 94000    |
# | train/             |          |
# |    actor_loss      | -51      |
# |    critic_loss     | 0.0979   |
# |    ent_coef        | 0.00362  |
# |    ent_coef_loss   | -7.81    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 93899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 944      |
# |    fps             | 70       |
# |    time_elapsed    | 1334     |
# |    total_timesteps | 94400    |
# | train/             |          |
# |    actor_loss      | -50.5    |
# |    critic_loss     | 0.0859   |
# |    ent_coef        | 0.00354  |
# |    ent_coef_loss   | -7.03    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 94299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 948      |
# |    fps             | 70       |
# |    time_elapsed    | 1339     |
# |    total_timesteps | 94800    |
# | train/             |          |
# |    actor_loss      | -50.2    |
# |    critic_loss     | 0.104    |
# |    ent_coef        | 0.00348  |
# |    ent_coef_loss   | -12.4    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 94699    |
# ---------------------------------
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 34
#      31 checkpoint_callback = setup_checkpoint_callback(checkpoint_dir=checkpoint_dir)
#      33 # Train and save
# ---> 34 model.learn(total_timesteps=total_timesteps, callback=checkpoint_callback)
#      35 model.save(f"{checkpoint_dir}/final_model")
#      37 env.close()
#
# File ~\anaconda3\envs\myenv\lib\site-packages\stable_baselines3\sac\sac.py:308, in SAC.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     299 def learn(
#     300     self: SelfSAC,
#     301     total_timesteps: int,
#    (...)
#     306     progress_bar: bool = False,
#     307 ) -> SelfSAC:
# --> 308     return super().learn(
#     309         total_timesteps=total_timesteps,
#     310         callback=callback,
#     311         log_interval=log_interval,
#     312         tb_log_name=tb_log_name,
#     313         reset_num_timesteps=reset_num_timesteps,
#     314         progress_bar=progress_bar,
#     315     )
#
# File ~\anaconda3\envs\myenv\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:328, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     325 assert isinstance(self.train_freq, TrainFreq)  # check done in _setup_learn()
#     327 while self.num_timesteps < total_timesteps:
# --> 328     rollout = self.collect_rollouts(
#     329         self.env,
#     330         train_freq=self.train_freq,
#     331         action_noise=self.action_noise,
#     332         callback=callback,
#     333         learning_starts=self.learning_starts,
#     334         replay_buffer=self.replay_buffer,
#     335         log_interval=log_interval,
#     336     )
#     338     if not rollout.continue_training:
#     339         break
#
# File ~\anaconda3\envs\myenv\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:568, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     566 callback.update_locals(locals())
#     567 # Only stop training if return value is False, not when it is None.
# --> 568 if not callback.on_step():
#     569     return RolloutReturn(num_collected_steps * env.num_envs, num_collected_episodes, continue_training=False)
#     571 # Retrieve reward and episode length if using Monitor wrapper
#
# File ~\anaconda3\envs\myenv\lib\site-packages\stable_baselines3\common\callbacks.py:114, in BaseCallback.on_step(self)
#     111 self.n_calls += 1
#     112 self.num_timesteps = self.model.num_timesteps
# --> 114 return self._on_step()
#
# File ~\anaconda3\envs\myenv\lib\site-packages\stable_baselines3\common\callbacks.py:309, in CheckpointCallback._on_step(self)
#     306 if self.save_replay_buffer and hasattr(self.model, "replay_buffer") and self.model.replay_buffer is not None:
#     307     # If model has a replay buffer, save it too
#     308     replay_buffer_path = self._checkpoint_path("replay_buffer_", extension="pkl")
# --> 309     self.model.save_replay_buffer(replay_buffer_path)  # type: ignore[attr-defined]
#     310     if self.verbose > 1:
#     311         print(f"Saving model replay buffer checkpoint to {replay_buffer_path}")
#
# File ~\anaconda3\envs\myenv\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:218, in OffPolicyAlgorithm.save_replay_buffer(self, path)
#     211 """
#     212 Save the replay buffer as a pickle file.
#     213
#     214 :param path: Path to the file where the replay buffer should be saved.
#     215     if path is a str or pathlib.Path, the path is automatically created if necessary.
#     216 """
#     217 assert self.replay_buffer is not None, "The replay buffer is not defined"
# --> 218 save_to_pkl(path, self.replay_buffer, self.verbose)
#
# File ~\anaconda3\envs\myenv\lib\site-packages\stable_baselines3\common\save_util.py:354, in save_to_pkl(path, obj, verbose)
#     351 file = open_path(path, "w", verbose=verbose, suffix="pkl")
#     352 # Use protocol>=4 to support saving replay buffers >= 4Gb
#     353 # See https://docs.python.org/3/library/pickle.html
# --> 354 pickle.dump(obj, file, protocol=pickle.HIGHEST_PROTOCOL)
#     355 if isinstance(path, (str, pathlib.Path)):
#     356     file.close()
#
# OSError: [Errno 28] No space left on device
