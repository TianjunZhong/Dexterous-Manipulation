# %%
import gymnasium as gym
import gymnasium_robotics
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv
from stable_baselines3.common.vec_env import VecNormalize

# %%
def setup_video_recorder(env, video_folder='videos/', record_freq=10000, video_length=200):
    """
    Wrap the environment with a video recorder to capture agent performances.
    """
    env = VecVideoRecorder(
        env,
        video_folder,
        record_video_trigger=lambda step: step % record_freq == 0,
        video_length=video_length,
        name_prefix='rl-agent'
    )
    return env

def setup_checkpoint_callback(checkpoint_dir='checkpoints/', save_freq=1000):
    """
    Create a callback that saves the model at regular intervals.
    """
    checkpoint_callback = CheckpointCallback(
        save_freq=save_freq,
        save_path=checkpoint_dir,
        name_prefix='rl_model',
        save_replay_buffer=True,
        save_vecnormalize=True,
        verbose=1
    )
    return checkpoint_callback

# %%
# Parameters
env_id = 'HandManipulateEgg-v1'
total_timesteps = 1000000
checkpoint_dir = './checkpoints/'
video_folder = './videos/'


def make_env():
    return gym.make("HandManipulateEgg-v1", reward_type='dense', render_mode='rgb_array')
env = DummyVecEnv([make_env])
env = VecNormalize(env, norm_obs=True, norm_reward=True)
env = setup_video_recorder(env, video_folder=video_folder)

# test making larger
policy_kwargs = dict(
    net_arch=dict(
        pi=[256, 256, 256],
        vf=[256, 256, 256]
    )
)

model = PPO("MultiInputPolicy", env, policy_kwargs=policy_kwargs, verbose=1)



model = PPO('MultiInputPolicy', env, verbose=1, policy_kwargs=policy_kwargs, tensorboard_log="./ppo_tensorboard/")


checkpoint_callback = setup_checkpoint_callback(checkpoint_dir=checkpoint_dir)

model.learn(total_timesteps=total_timesteps, callback=checkpoint_callback)
model.save(f"{checkpoint_dir}/final_model")

env.close()
# Out:
# Using cpu device
# Logging to ./ppo_tensorboard/PPO_4
# C:\Users\13233\anaconda3\envs\myenv\lib\site-packages\stable_baselines3\common\policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-0-to-step-200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-0-to-step-200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-0-to-step-200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-0-to-step-200.mp4
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    fps             | 361      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 342        |
# |    iterations           | 2          |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.11741668 |
# |    clip_fraction        | 0.571      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -28.4      |
# |    explained_variance   | -0.363     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.135     |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0949    |
# |    std                  | 0.998      |
# |    value_loss           | 0.298      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 327       |
# |    iterations           | 3         |
# |    time_elapsed         | 18        |
# |    total_timesteps      | 6144      |
# | train/                  |           |
# |    approx_kl            | 0.1451746 |
# |    clip_fraction        | 0.63      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -28.3     |
# |    explained_variance   | 0.173     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.139    |
# |    n_updates            | 20        |
# |    policy_gradient_loss | -0.108    |
# |    std                  | 0.996     |
# |    value_loss           | 0.0549    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 327        |
# |    iterations           | 4          |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.16539833 |
# |    clip_fraction        | 0.642      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -28.3      |
# |    explained_variance   | 0.418      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.131     |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.108     |
# |    std                  | 0.996      |
# |    value_loss           | 0.045      |
# ----------------------------------------
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-10000-to-step-10200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-10000-to-step-10200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-10000-to-step-10200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-10000-to-step-10200.mp4
# ---------------------------------------
# | rollout/                |           |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 321       |
# |    iterations           | 5         |
# |    time_elapsed         | 31        |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 0.1900878 |
# |    clip_fraction        | 0.657     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -28.3     |
# |    explained_variance   | 0.513     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.138    |
# |    n_updates            | 40        |
# |    policy_gradient_loss | -0.106    |
# |    std                  | 0.993     |
# |    value_loss           | 0.0411    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 321        |
# |    iterations           | 6          |
# |    time_elapsed         | 38         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.21822932 |
# |    clip_fraction        | 0.688      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -28.2      |
# |    explained_variance   | 0.769      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.139     |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.108     |
# |    std                  | 0.991      |
# |    value_loss           | 0.0324     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 322        |
# |    iterations           | 7          |
# |    time_elapsed         | 44         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.22305197 |
# |    clip_fraction        | 0.68       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -28.2      |
# |    explained_variance   | 0.33       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.142     |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.108     |
# |    std                  | 0.989      |
# |    value_loss           | 0.0303     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 323        |
# |    iterations           | 8          |
# |    time_elapsed         | 50         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.22316587 |
# |    clip_fraction        | 0.692      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -28.2      |
# |    explained_variance   | 0.617      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.133     |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.105     |
# |    std                  | 0.989      |
# |    value_loss           | 0.0324     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 323       |
# |    iterations           | 9         |
# |    time_elapsed         | 56        |
# |    total_timesteps      | 18432     |
# | train/                  |           |
# |    approx_kl            | 0.2581724 |
# |    clip_fraction        | 0.706     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -28.1     |
# |    explained_variance   | 0.721     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.138    |
# |    n_updates            | 80        |
# |    policy_gradient_loss | -0.111    |
# |    std                  | 0.986     |
# |    value_loss           | 0.0278    |
# ---------------------------------------
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-20000-to-step-20200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-20000-to-step-20200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-20000-to-step-20200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-20000-to-step-20200.mp4
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 319        |
# |    iterations           | 10         |
# |    time_elapsed         | 64         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.25273165 |
# |    clip_fraction        | 0.697      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -28.1      |
# |    explained_variance   | 0.83       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.128     |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.109     |
# |    std                  | 0.983      |
# |    value_loss           | 0.0241     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 315       |
# |    iterations           | 11        |
# |    time_elapsed         | 71        |
# |    total_timesteps      | 22528     |
# | train/                  |           |
# |    approx_kl            | 0.2771808 |
# |    clip_fraction        | 0.717     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -28       |
# |    explained_variance   | 0.833     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.142    |
# |    n_updates            | 100       |
# |    policy_gradient_loss | -0.109    |
# |    std                  | 0.978     |
# |    value_loss           | 0.0194    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 312        |
# |    iterations           | 12         |
# |    time_elapsed         | 78         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.32465422 |
# |    clip_fraction        | 0.721      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -27.9      |
# |    explained_variance   | 0.773      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.14      |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.109     |
# |    std                  | 0.976      |
# |    value_loss           | 0.017      |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    success_rate         | 0        |
# | time/                   |          |
# |    fps                  | 309      |
# |    iterations           | 13       |
# |    time_elapsed         | 86       |
# |    total_timesteps      | 26624    |
# | train/                  |          |
# |    approx_kl            | 0.321883 |
# |    clip_fraction        | 0.708    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -27.9    |
# |    explained_variance   | 0.768    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.135   |
# |    n_updates            | 120      |
# |    policy_gradient_loss | -0.104   |
# |    std                  | 0.975    |
# |    value_loss           | 0.0184   |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 308        |
# |    iterations           | 14         |
# |    time_elapsed         | 93         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.30678627 |
# |    clip_fraction        | 0.723      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -27.9      |
# |    explained_variance   | 0.899      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.146     |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.109     |
# |    std                  | 0.975      |
# |    value_loss           | 0.0155     |
# ----------------------------------------
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-30000-to-step-30200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-30000-to-step-30200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-30000-to-step-30200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-30000-to-step-30200.mp4
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 305        |
# |    iterations           | 15         |
# |    time_elapsed         | 100        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.33910376 |
# |    clip_fraction        | 0.727      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -27.8      |
# |    explained_variance   | 0.795      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.15      |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.108     |
# |    std                  | 0.972      |
# |    value_loss           | 0.0145     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 306       |
# |    iterations           | 16        |
# |    time_elapsed         | 106       |
# |    total_timesteps      | 32768     |
# | train/                  |           |
# |    approx_kl            | 0.3614496 |
# |    clip_fraction        | 0.736     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -27.8     |
# |    explained_variance   | 0.903     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.149    |
# |    n_updates            | 150       |
# |    policy_gradient_loss | -0.107    |
# |    std                  | 0.97      |
# |    value_loss           | 0.0125    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 307        |
# |    iterations           | 17         |
# |    time_elapsed         | 113        |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.33628872 |
# |    clip_fraction        | 0.727      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -27.7      |
# |    explained_variance   | 0.897      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.13      |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.104     |
# |    std                  | 0.968      |
# |    value_loss           | 0.0125     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 308        |
# |    iterations           | 18         |
# |    time_elapsed         | 119        |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.37120843 |
# |    clip_fraction        | 0.743      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -27.7      |
# |    explained_variance   | 0.866      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.144     |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.111     |
# |    std                  | 0.963      |
# |    value_loss           | 0.0108     |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    success_rate         | 0        |
# | time/                   |          |
# |    fps                  | 309      |
# |    iterations           | 19       |
# |    time_elapsed         | 125      |
# |    total_timesteps      | 38912    |
# | train/                  |          |
# |    approx_kl            | 0.401262 |
# |    clip_fraction        | 0.755    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -27.6    |
# |    explained_variance   | 0.9      |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.136   |
# |    n_updates            | 180      |
# |    policy_gradient_loss | -0.11    |
# |    std                  | 0.961    |
# |    value_loss           | 0.0112   |
# --------------------------------------
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-40000-to-step-40200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-40000-to-step-40200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-40000-to-step-40200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-40000-to-step-40200.mp4
# --------------------------------------
# | rollout/                |          |
# |    success_rate         | 0        |
# | time/                   |          |
# |    fps                  | 309      |
# |    iterations           | 20       |
# |    time_elapsed         | 132      |
# |    total_timesteps      | 40960    |
# | train/                  |          |
# |    approx_kl            | 0.388529 |
# |    clip_fraction        | 0.746    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -27.6    |
# |    explained_variance   | 0.921    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.122   |
# |    n_updates            | 190      |
# |    policy_gradient_loss | -0.104   |
# |    std                  | 0.96     |
# |    value_loss           | 0.0096   |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 310        |
# |    iterations           | 21         |
# |    time_elapsed         | 138        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.42148566 |
# |    clip_fraction        | 0.747      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -27.5      |
# |    explained_variance   | 0.906      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.135     |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.106     |
# |    std                  | 0.958      |
# |    value_loss           | 0.01       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 311        |
# |    iterations           | 22         |
# |    time_elapsed         | 144        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.43945423 |
# |    clip_fraction        | 0.749      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -27.5      |
# |    explained_variance   | 0.874      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.139     |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.109     |
# |    std                  | 0.957      |
# |    value_loss           | 0.0104     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 312        |
# |    iterations           | 23         |
# |    time_elapsed         | 150        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.46924818 |
# |    clip_fraction        | 0.755      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -27.5      |
# |    explained_variance   | 0.922      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.154     |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.113     |
# |    std                  | 0.954      |
# |    value_loss           | 0.00879    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 312        |
# |    iterations           | 24         |
# |    time_elapsed         | 157        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.49270812 |
# |    clip_fraction        | 0.754      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -27.4      |
# |    explained_variance   | 0.881      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.132     |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.105     |
# |    std                  | 0.954      |
# |    value_loss           | 0.00955    |
# ----------------------------------------
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-50000-to-step-50200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-50000-to-step-50200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-50000-to-step-50200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-50000-to-step-50200.mp4
# ---------------------------------------
# | rollout/                |           |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 312       |
# |    iterations           | 25        |
# |    time_elapsed         | 163       |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 0.5208669 |
# |    clip_fraction        | 0.756     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -27.4     |
# |    explained_variance   | 0.906     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.143    |
# |    n_updates            | 240       |
# |    policy_gradient_loss | -0.106    |
# |    std                  | 0.954     |
# |    value_loss           | 0.00719   |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 313        |
# |    iterations           | 26         |
# |    time_elapsed         | 170        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.54341114 |
# |    clip_fraction        | 0.766      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -27.4      |
# |    explained_variance   | 0.892      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.145     |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.11      |
# |    std                  | 0.95       |
# |    value_loss           | 0.00959    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 313        |
# |    iterations           | 27         |
# |    time_elapsed         | 176        |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.51009226 |
# |    clip_fraction        | 0.763      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -27.3      |
# |    explained_variance   | 0.837      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.137     |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.107     |
# |    std                  | 0.946      |
# |    value_loss           | 0.00724    |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 314       |
# |    iterations           | 28        |
# |    time_elapsed         | 182       |
# |    total_timesteps      | 57344     |
# | train/                  |           |
# |    approx_kl            | 0.5465316 |
# |    clip_fraction        | 0.761     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -27.3     |
# |    explained_variance   | 0.771     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.14     |
# |    n_updates            | 270       |
# |    policy_gradient_loss | -0.099    |
# |    std                  | 0.945     |
# |    value_loss           | 0.00708   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 315       |
# |    iterations           | 29        |
# |    time_elapsed         | 188       |
# |    total_timesteps      | 59392     |
# | train/                  |           |
# |    approx_kl            | 0.5761874 |
# |    clip_fraction        | 0.769     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -27.2     |
# |    explained_variance   | 0.897     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.15     |
# |    n_updates            | 280       |
# |    policy_gradient_loss | -0.109    |
# |    std                  | 0.942     |
# |    value_loss           | 0.00824   |
# ---------------------------------------
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-60000-to-step-60200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-60000-to-step-60200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-60000-to-step-60200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-60000-to-step-60200.mp4
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 314        |
# |    iterations           | 30         |
# |    time_elapsed         | 195        |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.52680176 |
# |    clip_fraction        | 0.762      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -27.1      |
# |    explained_variance   | 0.935      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.148     |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.106     |
# |    std                  | 0.938      |
# |    value_loss           | 0.00742    |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 315       |
# |    iterations           | 31        |
# |    time_elapsed         | 201       |
# |    total_timesteps      | 63488     |
# | train/                  |           |
# |    approx_kl            | 0.5645215 |
# |    clip_fraction        | 0.774     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -27.1     |
# |    explained_variance   | 0.848     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.113    |
# |    n_updates            | 300       |
# |    policy_gradient_loss | -0.102    |
# |    std                  | 0.936     |
# |    value_loss           | 0.00762   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 315       |
# |    iterations           | 32        |
# |    time_elapsed         | 207       |
# |    total_timesteps      | 65536     |
# | train/                  |           |
# |    approx_kl            | 0.6597918 |
# |    clip_fraction        | 0.782     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -27.1     |
# |    explained_variance   | 0.888     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.148    |
# |    n_updates            | 310       |
# |    policy_gradient_loss | -0.111    |
# |    std                  | 0.937     |
# |    value_loss           | 0.00625   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 316       |
# |    iterations           | 33        |
# |    time_elapsed         | 213       |
# |    total_timesteps      | 67584     |
# | train/                  |           |
# |    approx_kl            | 0.6167597 |
# |    clip_fraction        | 0.783     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -27.1     |
# |    explained_variance   | 0.914     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.148    |
# |    n_updates            | 320       |
# |    policy_gradient_loss | -0.111    |
# |    std                  | 0.935     |
# |    value_loss           | 0.00576   |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 316        |
# |    iterations           | 34         |
# |    time_elapsed         | 219        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.62434137 |
# |    clip_fraction        | 0.775      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -27        |
# |    explained_variance   | 0.881      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.119     |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.104     |
# |    std                  | 0.931      |
# |    value_loss           | 0.00617    |
# ----------------------------------------
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-70000-to-step-70200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-70000-to-step-70200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-70000-to-step-70200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-70000-to-step-70200.mp4
# ---------------------------------------
# | rollout/                |           |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 316       |
# |    iterations           | 35        |
# |    time_elapsed         | 226       |
# |    total_timesteps      | 71680     |
# | train/                  |           |
# |    approx_kl            | 0.6257741 |
# |    clip_fraction        | 0.775     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -26.9     |
# |    explained_variance   | 0.92      |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.144    |
# |    n_updates            | 340       |
# |    policy_gradient_loss | -0.107    |
# |    std                  | 0.927     |
# |    value_loss           | 0.00632   |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 316        |
# |    iterations           | 36         |
# |    time_elapsed         | 232        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.63708574 |
# |    clip_fraction        | 0.774      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -26.8      |
# |    explained_variance   | 0.879      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.128     |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.106     |
# |    std                  | 0.923      |
# |    value_loss           | 0.00697    |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 317       |
# |    iterations           | 37        |
# |    time_elapsed         | 238       |
# |    total_timesteps      | 75776     |
# | train/                  |           |
# |    approx_kl            | 0.6804476 |
# |    clip_fraction        | 0.786     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -26.7     |
# |    explained_variance   | 0.917     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.129    |
# |    n_updates            | 360       |
# |    policy_gradient_loss | -0.111    |
# |    std                  | 0.92      |
# |    value_loss           | 0.00509   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 317       |
# |    iterations           | 38        |
# |    time_elapsed         | 244       |
# |    total_timesteps      | 77824     |
# | train/                  |           |
# |    approx_kl            | 0.7475451 |
# |    clip_fraction        | 0.784     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -26.7     |
# |    explained_variance   | 0.875     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.116    |
# |    n_updates            | 370       |
# |    policy_gradient_loss | -0.102    |
# |    std                  | 0.92      |
# |    value_loss           | 0.00573   |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 318        |
# |    iterations           | 39         |
# |    time_elapsed         | 251        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.70440197 |
# |    clip_fraction        | 0.783      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -26.6      |
# |    explained_variance   | 0.927      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.14      |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.103     |
# |    std                  | 0.915      |
# |    value_loss           | 0.005      |
# ----------------------------------------
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-80000-to-step-80200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-80000-to-step-80200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-80000-to-step-80200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-80000-to-step-80200.mp4
# ---------------------------------------
# | rollout/                |           |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 317       |
# |    iterations           | 40        |
# |    time_elapsed         | 257       |
# |    total_timesteps      | 81920     |
# | train/                  |           |
# |    approx_kl            | 0.7905158 |
# |    clip_fraction        | 0.789     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -26.5     |
# |    explained_variance   | 0.928     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.128    |
# |    n_updates            | 390       |
# |    policy_gradient_loss | -0.111    |
# |    std                  | 0.912     |
# |    value_loss           | 0.00548   |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 318        |
# |    iterations           | 41         |
# |    time_elapsed         | 263        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.75244755 |
# |    clip_fraction        | 0.788      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -26.5      |
# |    explained_variance   | 0.905      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.136     |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.105     |
# |    std                  | 0.912      |
# |    value_loss           | 0.00488    |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 318       |
# |    iterations           | 42        |
# |    time_elapsed         | 270       |
# |    total_timesteps      | 86016     |
# | train/                  |           |
# |    approx_kl            | 0.7440867 |
# |    clip_fraction        | 0.784     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -26.5     |
# |    explained_variance   | 0.932     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.13     |
# |    n_updates            | 410       |
# |    policy_gradient_loss | -0.103    |
# |    std                  | 0.912     |
# |    value_loss           | 0.00371   |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 318        |
# |    iterations           | 43         |
# |    time_elapsed         | 276        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.77235854 |
# |    clip_fraction        | 0.797      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -26.5      |
# |    explained_variance   | 0.93       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.135     |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.106     |
# |    std                  | 0.912      |
# |    value_loss           | 0.00455    |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 318       |
# |    iterations           | 44        |
# |    time_elapsed         | 282       |
# |    total_timesteps      | 90112     |
# | train/                  |           |
# |    approx_kl            | 0.7593297 |
# |    clip_fraction        | 0.79      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -26.5     |
# |    explained_variance   | 0.88      |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.152    |
# |    n_updates            | 430       |
# |    policy_gradient_loss | -0.102    |
# |    std                  | 0.91      |
# |    value_loss           | 0.00575   |
# ---------------------------------------
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-90000-to-step-90200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-90000-to-step-90200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-90000-to-step-90200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-90000-to-step-90200.mp4
# ---------------------------------------
# | rollout/                |           |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 318       |
# |    iterations           | 45        |
# |    time_elapsed         | 289       |
# |    total_timesteps      | 92160     |
# | train/                  |           |
# |    approx_kl            | 0.9996568 |
# |    clip_fraction        | 0.802     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -26.5     |
# |    explained_variance   | 0.878     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.149    |
# |    n_updates            | 440       |
# |    policy_gradient_loss | -0.108    |
# |    std                  | 0.908     |
# |    value_loss           | 0.00516   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 318       |
# |    iterations           | 46        |
# |    time_elapsed         | 295       |
# |    total_timesteps      | 94208     |
# | train/                  |           |
# |    approx_kl            | 0.8631207 |
# |    clip_fraction        | 0.792     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -26.4     |
# |    explained_variance   | 0.871     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.123    |
# |    n_updates            | 450       |
# |    policy_gradient_loss | -0.0984   |
# |    std                  | 0.906     |
# |    value_loss           | 0.00775   |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 319        |
# |    iterations           | 47         |
# |    time_elapsed         | 301        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.85654294 |
# |    clip_fraction        | 0.798      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -26.4      |
# |    explained_variance   | 0.867      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.136     |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.104     |
# |    std                  | 0.905      |
# |    value_loss           | 0.00519    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 319        |
# |    iterations           | 48         |
# |    time_elapsed         | 307        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.88780874 |
# |    clip_fraction        | 0.793      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -26.3      |
# |    explained_variance   | 0.906      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.138     |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.105     |
# |    std                  | 0.903      |
# |    value_loss           | 0.00442    |
# ----------------------------------------
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-100000-to-step-100200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-100000-to-step-100200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-100000-to-step-100200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-100000-to-step-100200.mp4
# ---------------------------------------
# | rollout/                |           |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 319       |
# |    iterations           | 49        |
# |    time_elapsed         | 314       |
# |    total_timesteps      | 100352    |
# | train/                  |           |
# |    approx_kl            | 0.9342977 |
# |    clip_fraction        | 0.793     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -26.3     |
# |    explained_variance   | 0.916     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.135    |
# |    n_updates            | 480       |
# |    policy_gradient_loss | -0.103    |
# |    std                  | 0.901     |
# |    value_loss           | 0.00436   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 319       |
# |    iterations           | 50        |
# |    time_elapsed         | 320       |
# |    total_timesteps      | 102400    |
# | train/                  |           |
# |    approx_kl            | 0.8856528 |
# |    clip_fraction        | 0.8       |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -26.3     |
# ...
# |    clip_fraction        | 0.901    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -14.9    |
# |    explained_variance   | 0.936    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.105   |
# |    n_updates            | 4720     |
# |    policy_gradient_loss | -0.0702  |
# |    std                  | 0.512    |
# |    value_loss           | 0.00333  |
# --------------------------------------
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-970000-to-step-970200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-970000-to-step-970200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-970000-to-step-970200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-970000-to-step-970200.mp4
# ---------------------------------------
# | rollout/                |           |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 323       |
# |    iterations           | 474       |
# |    time_elapsed         | 2996      |
# |    total_timesteps      | 970752    |
# | train/                  |           |
# |    approx_kl            | 22.419868 |
# |    clip_fraction        | 0.904     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.9     |
# |    explained_variance   | 0.95      |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.123    |
# |    n_updates            | 4730      |
# |    policy_gradient_loss | -0.0638   |
# |    std                  | 0.511     |
# |    value_loss           | 0.00351   |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    success_rate         | 0        |
# | time/                   |          |
# |    fps                  | 323      |
# |    iterations           | 475      |
# |    time_elapsed         | 3002     |
# |    total_timesteps      | 972800   |
# | train/                  |          |
# |    approx_kl            | 18.57459 |
# |    clip_fraction        | 0.905    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -14.9    |
# |    explained_variance   | 0.968    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0741  |
# |    n_updates            | 4740     |
# |    policy_gradient_loss | -0.0627  |
# |    std                  | 0.511    |
# |    value_loss           | 0.00357  |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 324       |
# |    iterations           | 476       |
# |    time_elapsed         | 3008      |
# |    total_timesteps      | 974848    |
# | train/                  |           |
# |    approx_kl            | 25.975788 |
# |    clip_fraction        | 0.912     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.9     |
# |    explained_variance   | 0.971     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.117    |
# |    n_updates            | 4750      |
# |    policy_gradient_loss | -0.0514   |
# |    std                  | 0.512     |
# |    value_loss           | 0.00303   |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    success_rate         | 0        |
# | time/                   |          |
# |    fps                  | 324      |
# |    iterations           | 477      |
# |    time_elapsed         | 3014     |
# |    total_timesteps      | 976896   |
# | train/                  |          |
# |    approx_kl            | 24.2094  |
# |    clip_fraction        | 0.903    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -14.9    |
# |    explained_variance   | 0.961    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.138   |
# |    n_updates            | 4760     |
# |    policy_gradient_loss | -0.0698  |
# |    std                  | 0.512    |
# |    value_loss           | 0.00332  |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 324       |
# |    iterations           | 478       |
# |    time_elapsed         | 3021      |
# |    total_timesteps      | 978944    |
# | train/                  |           |
# |    approx_kl            | 13.175068 |
# |    clip_fraction        | 0.91      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.9     |
# |    explained_variance   | 0.961     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.113    |
# |    n_updates            | 4770      |
# |    policy_gradient_loss | -0.0604   |
# |    std                  | 0.512     |
# |    value_loss           | 0.0034    |
# ---------------------------------------
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-980000-to-step-980200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-980000-to-step-980200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-980000-to-step-980200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-980000-to-step-980200.mp4
# --------------------------------------
# | rollout/                |          |
# |    success_rate         | 0        |
# | time/                   |          |
# |    fps                  | 324      |
# |    iterations           | 479      |
# |    time_elapsed         | 3027     |
# |    total_timesteps      | 980992   |
# | train/                  |          |
# |    approx_kl            | 20.28061 |
# |    clip_fraction        | 0.904    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -14.9    |
# |    explained_variance   | 0.923    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0965  |
# |    n_updates            | 4780     |
# |    policy_gradient_loss | -0.0661  |
# |    std                  | 0.511    |
# |    value_loss           | 0.00474  |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    success_rate         | 0        |
# | time/                   |          |
# |    fps                  | 324      |
# |    iterations           | 480      |
# |    time_elapsed         | 3033     |
# |    total_timesteps      | 983040   |
# | train/                  |          |
# |    approx_kl            | 15.87548 |
# |    clip_fraction        | 0.908    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -14.8    |
# |    explained_variance   | 0.957    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.113   |
# |    n_updates            | 4790     |
# |    policy_gradient_loss | -0.0579  |
# |    std                  | 0.51     |
# |    value_loss           | 0.00386  |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 324       |
# |    iterations           | 481       |
# |    time_elapsed         | 3040      |
# |    total_timesteps      | 985088    |
# | train/                  |           |
# |    approx_kl            | 32.155426 |
# |    clip_fraction        | 0.898     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.8     |
# |    explained_variance   | 0.941     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.129    |
# |    n_updates            | 4800      |
# |    policy_gradient_loss | -0.077    |
# |    std                  | 0.511     |
# |    value_loss           | 0.00517   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 324       |
# |    iterations           | 482       |
# |    time_elapsed         | 3046      |
# |    total_timesteps      | 987136    |
# | train/                  |           |
# |    approx_kl            | 17.328339 |
# |    clip_fraction        | 0.901     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.8     |
# |    explained_variance   | 0.947     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.101    |
# |    n_updates            | 4810      |
# |    policy_gradient_loss | -0.0439   |
# |    std                  | 0.51      |
# |    value_loss           | 0.00332   |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    success_rate         | 0        |
# | time/                   |          |
# |    fps                  | 324      |
# |    iterations           | 483      |
# |    time_elapsed         | 3052     |
# |    total_timesteps      | 989184   |
# | train/                  |          |
# |    approx_kl            | 32.24504 |
# |    clip_fraction        | 0.905    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -14.8    |
# |    explained_variance   | 0.95     |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.115   |
# |    n_updates            | 4820     |
# |    policy_gradient_loss | -0.0622  |
# |    std                  | 0.508    |
# |    value_loss           | 0.0049   |
# --------------------------------------
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-990000-to-step-990200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-990000-to-step-990200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-990000-to-step-990200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-990000-to-step-990200.mp4
# ---------------------------------------
# | rollout/                |           |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 324       |
# |    iterations           | 484       |
# |    time_elapsed         | 3059      |
# |    total_timesteps      | 991232    |
# | train/                  |           |
# |    approx_kl            | 159.79828 |
# |    clip_fraction        | 0.912     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.7     |
# |    explained_variance   | 0.951     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.12     |
# |    n_updates            | 4830      |
# |    policy_gradient_loss | -0.0697   |
# |    std                  | 0.508     |
# |    value_loss           | 0.00371   |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 324        |
# |    iterations           | 485        |
# |    time_elapsed         | 3065       |
# |    total_timesteps      | 993280     |
# | train/                  |            |
# |    approx_kl            | 14.4184265 |
# |    clip_fraction        | 0.906      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -14.7      |
# |    explained_variance   | 0.959      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.125     |
# |    n_updates            | 4840       |
# |    policy_gradient_loss | -0.0635    |
# |    std                  | 0.506      |
# |    value_loss           | 0.0044     |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    success_rate         | 0        |
# | time/                   |          |
# |    fps                  | 324      |
# |    iterations           | 486      |
# |    time_elapsed         | 3071     |
# |    total_timesteps      | 995328   |
# | train/                  |          |
# |    approx_kl            | 18.5541  |
# |    clip_fraction        | 0.902    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -14.7    |
# |    explained_variance   | 0.956    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.125   |
# |    n_updates            | 4850     |
# |    policy_gradient_loss | -0.0759  |
# |    std                  | 0.506    |
# |    value_loss           | 0.00311  |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 324       |
# |    iterations           | 487       |
# |    time_elapsed         | 3077      |
# |    total_timesteps      | 997376    |
# | train/                  |           |
# |    approx_kl            | 22.463572 |
# |    clip_fraction        | 0.903     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.6     |
# |    explained_variance   | 0.97      |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0735   |
# |    n_updates            | 4860      |
# |    policy_gradient_loss | -0.0695   |
# |    std                  | 0.504     |
# |    value_loss           | 0.00418   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 324       |
# |    iterations           | 488       |
# |    time_elapsed         | 3083      |
# |    total_timesteps      | 999424    |
# | train/                  |           |
# |    approx_kl            | 44.475693 |
# |    clip_fraction        | 0.901     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.6     |
# |    explained_variance   | 0.957     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0897   |
# |    n_updates            | 4870      |
# |    policy_gradient_loss | -0.0577   |
# |    std                  | 0.504     |
# |    value_loss           | 0.0044    |
# ---------------------------------------
# Saving video to C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-1000000-to-step-1000200.mp4
# MoviePy - Building video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-1000000-to-step-1000200.mp4.
# MoviePy - Writing video C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-1000000-to-step-1000200.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\13233\Documents\Robotics Project\Dexterous-Manipulation\videos\rl-agent-step-1000000-to-step-1000200.mp4
# ---------------------------------------
# | rollout/                |           |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 324       |
# |    iterations           | 489       |
# |    time_elapsed         | 3090      |
# |    total_timesteps      | 1001472   |
# | train/                  |           |
# |    approx_kl            | 19.913387 |
# |    clip_fraction        | 0.9       |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.6     |
# |    explained_variance   | 0.968     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.119    |
# |    n_updates            | 4880      |
# |    policy_gradient_loss | -0.0583   |
# |    std                  | 0.504     |
# |    value_loss           | 0.0045    |
# ---------------------------------------
